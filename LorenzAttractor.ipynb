# %% [markdown]
# The Lorenz attractor is a mathematical model first proposed by Edward Lorenz, a meteorologist, in 1963. It is a simple nonlinear system used to model complex phenomena observed in the real world.
#
# The Lorenz attractor exhibits various dynamic behaviors in three-dimensional space, known as "chaotic behavior," where future states are extremely sensitive to small differences in initial conditions. This model was initially developed to explain the unpredictable nature of large-scale motions in the atmosphere.
#
# The Lorenz attractor is described by the following set of differential equations:
#
# dx/dt=σ(y-x),
# dy/dt=x(ρ-z)-y,
# dz/dt=xy-βz
#
# Here, x, y and z are the variables of the system, and σ, ρ, and β are parameters of the system. These equations trace out trajectories in a three-dimensional state space, where the trajectories do not converge to a particular point but exhibit complex oscillations. This is one of the defining characteristics of the Lorenz attractor.
#
# This model is considered an important example in the field of chaos theory and provides a fundamental basis for understanding dynamic behaviors in weather prediction, climate modeling, and other complex systems.

# %%
from manim import *
import numpy as np

class LorenzAttractor(Scene):
    def construct(self):
        self.create_lorenz_attractor()

    def lorenz_system(self, pos, sigma=10, rho=28, beta=8/3):
        x, y, z = pos
        dx_dt = sigma * (y - x)
        dy_dt = x * (rho - z) - y
        dz_dt = x * y - beta * z
        return np.array([dx_dt, dy_dt, dz_dt])

    def rate_to_color(self, rate, min_rate, max_rate):
        rate_log = np.log(rate)
        min_rate_log = np.log(min_rate)
        max_rate_log = np.log(max_rate)
        rate_normalized = (rate_log - min_rate_log) / (max_rate_log - min_rate_log)
        return interpolate_color(BLUE, RED, rate_normalized)

    def create_lorenz_attractor(self):
        # Initial position
        pos = np.array([-1.0, 1.0, 0.0])

        # Parameters for the animation
        dt = 0.001
        steps = 50000
        scale_factor = 0.14
        dt_scaling_factor = 0.1

        # Create a curve from the initial position
        curve = ParametricFunction(
            lambda t: pos,
            t_range=[0, 1, 0.1],
            color=YELLOW,
        )

        min_rate = float("inf")
        max_rate = float("-inf")

        # Calculate min_rate and max_rate
        for _ in range(steps):
            dp = self.lorenz_system(pos) * dt
            rate = np.linalg.norm(dp)
            min_rate = min(min_rate, rate)
            max_rate = max(max_rate, rate)
            pos += dp

        # Reset initial position
        pos = np.array([-1.0, 1.0, 0.0])

        # Create segments with color based on rate of change
        for _ in range(steps):
            dp = self.lorenz_system(pos) * dt
            rate = np.linalg.norm(dp)
            segment_color = self.rate_to_color(rate, min_rate, max_rate)
            segment = Line(pos - dp, pos, color=segment_color, stroke_width=2)
            curve.add(segment)
            pos += dp

            # Adjust time step based on rate of change
            adaptive_dt = dt * dt_scaling_factor / rate
            pos += dp * adaptive_dt

        curve.scale(scale_factor)
        curve.move_to(ORIGIN)  # Center the curve in the scene
        self.play(Create(curve), run_time=20, rate_func=linear)
        self.wait()

if __name__ == "__main__":
    import sys
    from pathlib import Path
    import os

    if "--play" in sys.argv:
        script_name = f"{Path(__file__).resolve()}"
        os.system(f"manim -p -ql -i {script_name}")

# %%
manim  -qm LorenzAttractor
